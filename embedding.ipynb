# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\Users\nico_\Desktop\Data science bootcamp\Deep Learning\RNN project\rnnvenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Sentences
sent=['the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developper',
    'understand the meaning of words',
    'you videos are good']

# %%
# Define the vocabulary size
voc_size=10000

# %%
# One hot representation
one_hot_rep=[one_hot(words,voc_size)for words in sent]

# %%
one_hot_rep
# Out:
# [[1166, 5534, 8539, 9647],
#  [1166, 5534, 8539, 3927],
#  [1166, 6129, 8539, 5605],
#  [1877, 7682, 8973, 3974, 5438],
#  [1877, 7682, 8973, 3974, 7659],
#  [4041, 1166, 5019, 8539, 8893],
#  [8714, 4486, 2669, 3974]]

# %%
# Word embedding representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_rep,padding='pre',maxlen=sent_length)

# %%
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 1166, 5534, 8539, 9647],
#        [   0,    0,    0,    0, 1166, 5534, 8539, 3927],
#        [   0,    0,    0,    0, 1166, 6129, 8539, 5605],
#        [   0,    0,    0, 1877, 7682, 8973, 3974, 5438],
#        [   0,    0,    0, 1877, 7682, 8973, 3974, 7659],
#        [   0,    0,    0, 4041, 1166, 5019, 8539, 8893],
#        [   0,    0,    0,    0, 8714, 4486, 2669, 3974]])

# %%
# Feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\nico_\Desktop\Data science bootcamp\Deep Learning\RNN project\rnnvenv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\nico_\Desktop\Data science bootcamp\Deep Learning\RNN project\rnnvenv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 136ms/step
# array([[[ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.03008181, -0.03316828, -0.00712879,  0.04661567,
#           0.01870611, -0.04883964,  0.02188322,  0.01308144,
#          -0.0101015 , -0.01913465],
#         [ 0.0387259 , -0.00846404,  0.0215295 , -0.01467887,
#          -0.02622956, -0.04255241, -0.03422225,  0.01228912,
#           0.03784731, -0.03676242],
#         [ 0.0253158 ,  0.04295889,  0.01188999, -0.03974878,
#           0.02926054,  0.03625187,  0.03494293, -0.01321293,
#           0.00705949,  0.04753761],
#         [ 0.03333994, -0.04887644,  0.01465417, -0.01102389,
#          -0.02582737,  0.02352561, -0.04864264,  0.02072709,
#           0.01275573, -0.0041214 ]],
#
#        [[ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.03008181, -0.03316828, -0.00712879,  0.04661567,
#           0.01870611, -0.04883964,  0.02188322,  0.01308144,
#          -0.0101015 , -0.01913465],
#         [ 0.0387259 , -0.00846404,  0.0215295 , -0.01467887,
#          -0.02622956, -0.04255241, -0.03422225,  0.01228912,
#           0.03784731, -0.03676242],
#         [ 0.0253158 ,  0.04295889,  0.01188999, -0.03974878,
#           0.02926054,  0.03625187,  0.03494293, -0.01321293,
#           0.00705949,  0.04753761],
#         [-0.02782924, -0.02007015, -0.04395688,  0.03965659,
#           0.00591405, -0.03447773, -0.04486201, -0.04010465,
#           0.0366189 ,  0.01945784]],
#
#        [[ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.03008181, -0.03316828, -0.00712879,  0.04661567,
#           0.01870611, -0.04883964,  0.02188322,  0.01308144,
#          -0.0101015 , -0.01913465],
#         [-0.02590013, -0.02373904,  0.03330838, -0.04518923,
#          -0.02961257,  0.046085  , -0.03306284,  0.00855301,
#           0.03946705, -0.01947978],
#         [ 0.0253158 ,  0.04295889,  0.01188999, -0.03974878,
#           0.02926054,  0.03625187,  0.03494293, -0.01321293,
#           0.00705949,  0.04753761],
#         [-0.03510458,  0.03854295, -0.01123077,  0.041047  ,
#           0.04052712, -0.04601092, -0.04654717, -0.01137693,
#          -0.02837699,  0.01819411]],
#
#        [[ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [-0.02254046,  0.01999019,  0.04939562, -0.02160456,
#          -0.02368126,  0.03786511,  0.03178102, -0.00379451,
#           0.03363028,  0.00787761],
#         [-0.03653834, -0.04173344,  0.00154708,  0.00097188,
#          -0.04205686, -0.00981037, -0.00349983,  0.02686818,
#          -0.04991983,  0.03946855],
#         [ 0.03301447, -0.02106865, -0.01393665, -0.01025802,
#           0.0012021 ,  0.0021636 ,  0.00306488,  0.01728949,
#           0.01138628,  0.0478385 ],
#         [ 0.00886476, -0.02186536,  0.04844424,  0.02775282,
#           0.00220468, -0.04605417, -0.0067052 ,  0.02385875,
#          -0.04600295, -0.02017382],
#         [ 0.03691358, -0.04115339, -0.04363651,  0.03844802,
#          -0.03403293,  0.00867469, -0.01774236,  0.04655776,
#           0.03718683, -0.02804848]],
#
#        [[ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [-0.02254046,  0.01999019,  0.04939562, -0.02160456,
#          -0.02368126,  0.03786511,  0.03178102, -0.00379451,
#           0.03363028,  0.00787761],
#         [-0.03653834, -0.04173344,  0.00154708,  0.00097188,
#          -0.04205686, -0.00981037, -0.00349983,  0.02686818,
#          -0.04991983,  0.03946855],
#         [ 0.03301447, -0.02106865, -0.01393665, -0.01025802,
#           0.0012021 ,  0.0021636 ,  0.00306488,  0.01728949,
#           0.01138628,  0.0478385 ],
#         [ 0.00886476, -0.02186536,  0.04844424,  0.02775282,
#           0.00220468, -0.04605417, -0.0067052 ,  0.02385875,
#          -0.04600295, -0.02017382],
#         [ 0.00996783,  0.04351657, -0.03342678, -0.02131468,
#           0.03015257, -0.0288374 ,  0.00564669, -0.02433925,
#          -0.02120065, -0.02296534]],
#
#        [[ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [-0.02772579, -0.04919878,  0.02958385, -0.03744185,
#          -0.02532849,  0.03558601,  0.04332802,  0.03594114,
#          -0.0075968 , -0.02001797],
#         [ 0.03008181, -0.03316828, -0.00712879,  0.04661567,
#           0.01870611, -0.04883964,  0.02188322,  0.01308144,
#          -0.0101015 , -0.01913465],
#         [-0.01895514, -0.00079966, -0.00993044,  0.02492866,
#           0.03320852, -0.01788018, -0.02263733,  0.01503341,
#          -0.04460545,  0.02845312],
#         [ 0.0253158 ,  0.04295889,  0.01188999, -0.03974878,
#           0.02926054,  0.03625187,  0.03494293, -0.01321293,
#           0.00705949,  0.04753761],
#         [ 0.04428417, -0.01984587, -0.01734128,  0.04060389,
#          -0.04804531,  0.01140296,  0.00094156,  0.03788146,
#          -0.01286609, -0.034623  ]],
#
#        [[ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [ 0.01683379,  0.04313221, -0.00722742, -0.03867586,
#          -0.00367073, -0.03172326,  0.03986007,  0.0489147 ,
#          -0.00216191,  0.03647989],
#         [-0.04502231, -0.03711684,  0.00619218, -0.04894387,
#           0.049364  , -0.01302141,  0.0396934 ,  0.00670942,
#           0.01204056,  0.01375128],
#         [ 0.02388724, -0.0387601 , -0.03222011, -0.01891336,
#           0.04626301, -0.04872362,  0.02284178, -0.02695546,
#           0.03659285,  0.00610362],
#         [-0.00514964,  0.00787487, -0.02190684, -0.01945082,
#          -0.03336553, -0.04347299,  0.00486567, -0.00519153,
#          -0.03080142, -0.04663153],
#         [ 0.00886476, -0.02186536,  0.04844424,  0.02775282,
#           0.00220468, -0.04605417, -0.0067052 ,  0.02385875,
#          -0.04600295, -0.02017382]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 1166, 5534, 8539, 9647])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 45ms/step
# array([[ 0.01683379,  0.04313221, -0.00722742, -0.03867586, -0.00367073,
#         -0.03172326,  0.03986007,  0.0489147 , -0.00216191,  0.03647989],
#        [ 0.01683379,  0.04313221, -0.00722742, -0.03867586, -0.00367073,
#         -0.03172326,  0.03986007,  0.0489147 , -0.00216191,  0.03647989],
#        [ 0.01683379,  0.04313221, -0.00722742, -0.03867586, -0.00367073,
#         -0.03172326,  0.03986007,  0.0489147 , -0.00216191,  0.03647989],
#        [ 0.01683379,  0.04313221, -0.00722742, -0.03867586, -0.00367073,
#         -0.03172326,  0.03986007,  0.0489147 , -0.00216191,  0.03647989],
#        [ 0.03008181, -0.03316828, -0.00712879,  0.04661567,  0.01870611,
#         -0.04883964,  0.02188322,  0.01308144, -0.0101015 , -0.01913465],
#        [ 0.0387259 , -0.00846404,  0.0215295 , -0.01467887, -0.02622956,
#         -0.04255241, -0.03422225,  0.01228912,  0.03784731, -0.03676242],
#        [ 0.0253158 ,  0.04295889,  0.01188999, -0.03974878,  0.02926054,
#          0.03625187,  0.03494293, -0.01321293,  0.00705949,  0.04753761],
#        [ 0.03333994, -0.04887644,  0.01465417, -0.01102389, -0.02582737,
#          0.02352561, -0.04864264,  0.02072709,  0.01275573, -0.0041214 ]],
#       dtype=float32)

# %% [markdown]
# Chaque mot est converti en un vecteur de dimension 10 dans une phrase de longueur 8
